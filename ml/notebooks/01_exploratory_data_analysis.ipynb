# %% [markdown]
# # King County Housing Sales: Exploratory Data Analysis
# This notebook provides reproducible statistical profiling, feature correlation analysis, and geographic market distributions on the 21,613 authentic King County sales.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('../../data/processed/kc_house_data_cleaned.csv')
print(f'Observations: {df.shape[0]}, Features: {df.shape[1]}')
df.head()

# %%
# Statistical Summary of Price Target
df['price'].describe().to_frame()

# %%
# Top correlations with sale price
numeric_cols = ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'waterfront', 'view_score', 'condition_score', 'grade_score', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'latitude', 'longitude', 'sqft_living15', 'sqft_lot15']
corr = df[numeric_cols].corr()['price'].sort_values(ascending=False)
corr.to_frame(name='Pearson Correlation with Price')
